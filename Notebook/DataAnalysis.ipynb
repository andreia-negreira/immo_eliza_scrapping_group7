# %%
import pandas as pd
import numpy as np

# %%
df_house= pd.read_csv("Data/HOUSES.csv")

# %%
df_house.head()
# Out:
#    Unnamed: 0        id Locality  Postcode            Street   Number  \
# 0           0  10686031  Seraing    4100.0     Place Merlot         6
# 1           1  10686030  Seraing    4100.0     Place Merlot         6
# 2           2  10686027     Lede    9340.0       Hoogstraat        20
# 3           3  10686410      NaN       NaN           No info  No info
# 4           4  10686063     Gent    9000.0  Sint-Denijslaan         1
#
#   Type of property Subtype of property   Price Type of sale  ...  Open fire  \
# 0            HOUSE               HOUSE  144000     FOR_SALE  ...         No
# 1            HOUSE               HOUSE  199000     FOR_SALE  ...         No
# 2            HOUSE               VILLA  539000     FOR_SALE  ...         No
# 3            HOUSE               HOUSE  650000     FOR_SALE  ...         No
# 4            HOUSE  MIXED_USE_BUILDING  850000     FOR_SALE  ...         No
#
#    Terrace TerraceArea Garden Garden area Surface of the land  \
# 0      Yes         NaN    Yes        25.0                 105
# 1      Yes       108.0    Yes        28.0                 229
# 2      Yes        60.0     No         NaN                 911
# 3      Yes        10.0    Yes        90.0                 170
# 4      Yes         NaN     No         NaN                 430
#
#    Surface area of the plot of land Number of facades   Swimming pool  \
# 0                                 0                 2              No
# 1                               104                 2              No
# 2                               541                 4              No
# 3                               -45                 2              No
# 4                              -834                 2              No
#
#    State of the building
# 0                   GOOD
# 1                   GOOD
# 2                 AS_NEW
# 3          TO_BE_DONE_UP
# 4            TO_RENOVATE
#
# [5 rows x 24 columns]

# %%
df_house.shape
# Out:
# (9873, 24)

# %%
df_apartement= pd.read_csv("data/APARTMENTS.csv")

# %%
df_apartement.head()
# Out:
#    Unnamed: 0        id Locality  Postcode               Street   Number  \
# 0           0  10687298      NaN       NaN              No info  No info
# 1           1  10686321   Oupeye    4680.0  Rue de la Wallonie        2A
# 2           2  10686750    Ronse    9600.0          Hoogstraat         5
# 3           3  10686062     Gent    9000.0     Sint-Denijslaan         1
# 4           4  10685792      NaN       NaN              No info  No info
#
#   Type of property Subtype of property   Price Type of sale  ...  Open fire  \
# 0        APARTMENT           APARTMENT  170000     FOR_SALE  ...         No
# 1        APARTMENT           APARTMENT  219000     FOR_SALE  ...         No
# 2        APARTMENT           APARTMENT  219000     FOR_SALE  ...         No
# 3        APARTMENT        SERVICE_FLAT  245000     FOR_SALE  ...         No
# 4        APARTMENT           APARTMENT  330000     FOR_SALE  ...         No
#
#    Terrace TerraceArea Garden Garden area Surface of the land  \
# 0      Yes         2.0     No         NaN             No info
# 1      Yes        21.0    Yes        46.0                 NaN
# 2       No         NaN    Yes      2000.0                 NaN
# 3      Yes        10.0     No         NaN             No info
# 4      Yes         8.0     No         NaN             No info
#
#    Surface area of the plot of land Number of facades   Swimming pool  \
# 0                           No info                 2              No
# 1                           No info                 4              No
# 2                           No info                 4              No
# 3                           No info                 2              No
# 4                           No info                 2              No
#
#   State of the building
# 0                  GOOD
# 1                  GOOD
# 2                  GOOD
# 3                AS_NEW
# 4                  GOOD
#
# [5 rows x 24 columns]

# %%
df= pd.concat([df_house,df_apartement])

# %%
df.shape
# Out:
# (19746, 24)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    Unnamed: 0        id Locality  Postcode            Street   Number  \
# 0           0  10686031  Seraing    4100.0     Place Merlot         6
# 1           1  10686030  Seraing    4100.0     Place Merlot         6
# 2           2  10686027     Lede    9340.0       Hoogstraat        20
# 3           3  10686410      NaN       NaN           No info  No info
# 4           4  10686063     Gent    9000.0  Sint-Denijslaan         1
#
#   Type of property Subtype of property   Price Type of sale  ...  Open fire  \
# 0            HOUSE               HOUSE  144000     FOR_SALE  ...         No
# 1            HOUSE               HOUSE  199000     FOR_SALE  ...         No
# 2            HOUSE               VILLA  539000     FOR_SALE  ...         No
# 3            HOUSE               HOUSE  650000     FOR_SALE  ...         No
# 4            HOUSE  MIXED_USE_BUILDING  850000     FOR_SALE  ...         No
#
#    Terrace TerraceArea Garden Garden area Surface of the land  \
# 0      Yes         NaN    Yes        25.0                 105
# 1      Yes       108.0    Yes        28.0                 229
# 2      Yes        60.0     No         NaN                 911
# 3      Yes        10.0    Yes        90.0                 170
# 4      Yes         NaN     No         NaN                 430
#
#    Surface area of the plot of land Number of facades   Swimming pool  \
# 0                                 0                 2              No
# 1                               104                 2              No
# 2                               541                 4              No
# 3                               -45                 2              No
# 4                              -834                 2              No
#
#   State of the building
# 0                  GOOD
# 1                  GOOD
# 2                AS_NEW
# 3         TO_BE_DONE_UP
# 4           TO_RENOVATE
#
# [5 rows x 24 columns]

# %%
df.loc[df['Garden'] == 'No', 'Garden area'] = 0

# %%
df.loc[df['Terrace'] == 'No', 'TerraceArea'] = 0

# %%
df.head(10)
# Out:
#    Unnamed: 0        id    Locality  Postcode                Street   Number  \
# 0           0  10686031     Seraing    4100.0         Place Merlot         6
# 1           1  10686030     Seraing    4100.0         Place Merlot         6
# 2           2  10686027        Lede    9340.0           Hoogstraat        20
# 3           3  10686410         NaN       NaN               No info  No info
# 4           4  10686063        Gent    9000.0      Sint-Denijslaan         1
# 5           5  10686170    Mechelen    2800.0           Hoogstraat         5
# 6           6  10683651       Trooz    4870.0            Grand rue       191
# 7           7  10683687  Bruxelles     1000.0      Square Ambiorix        40
# 8           8  10685116      Hotton    6990.0            Rue Simon      46/2
# 9           9  10684680       Dworp    1653.0  Alsembergsesteenweg       660
#
#   Type of property Subtype of property    Price Type of sale  ...  Open fire  \
# 0            HOUSE               HOUSE   144000     FOR_SALE  ...         No
# 1            HOUSE               HOUSE   199000     FOR_SALE  ...         No
# 2            HOUSE               VILLA   539000     FOR_SALE  ...         No
# 3            HOUSE               HOUSE   650000     FOR_SALE  ...         No
# 4            HOUSE  MIXED_USE_BUILDING   850000     FOR_SALE  ...         No
# 5            HOUSE     APARTMENT_BLOCK  1295000     FOR_SALE  ...         No
# 6            HOUSE               HOUSE   160000     FOR_SALE  ...         No
# 7            HOUSE               HOUSE   250000     FOR_SALE  ...         No
# 8            HOUSE     APARTMENT_BLOCK   325000     FOR_SALE  ...         No
# 9            HOUSE               HOUSE   399000     FOR_SALE  ...        NaN
#
#    Terrace TerraceArea Garden Garden area Surface of the land  \
# 0      Yes         NaN    Yes        25.0                 105
# 1      Yes       108.0    Yes        28.0                 229
# 2      Yes        60.0     No         0.0                 911
# 3      Yes        10.0    Yes        90.0                 170
# 4      Yes         NaN     No         0.0                 430
# 5      Yes         NaN    Yes        95.0                 171
# 6      Yes        14.0     No         0.0                 116
# 7       No         0.0     No         0.0                  17
# 8       No         0.0     No         0.0                 122
# 9       No         0.0    Yes      1113.0                1329
#
#    Surface area of the plot of land Number of facades   Swimming pool  \
# 0                                 0                 2              No
# 1                               104                 2              No
# 2                               541                 4              No
# 3                               -45                 2              No
# 4                              -834                 2              No
# 5                               -55                 2              No
# 6                               -14                 3              No
# 7                               -58                 2              No
# 8                              -113                 2              No
# 9                              1113                 4              No
#
#   State of the building
# 0                  GOOD
# 1                  GOOD
# 2                AS_NEW
# 3         TO_BE_DONE_UP
# 4           TO_RENOVATE
# 5                AS_NEW
# 6           TO_RENOVATE
# 7            TO_RESTORE
# 8                  GOOD
# 9           TO_RENOVATE
#
# [10 rows x 24 columns]

# %%
df.to_csv('df_total.csv', index=False)

# %%
df.shape
# Out:
# (19746, 24)

# %%
df
# Out:
#       Unnamed: 0        id         Locality  Postcode              Street  \
# 0              0  10686031          Seraing    4100.0       Place Merlot
# 1              1  10686030          Seraing    4100.0       Place Merlot
# 2              2  10686027             Lede    9340.0         Hoogstraat
# 3              3  10686410              NaN       NaN             No info
# 4              4  10686063             Gent    9000.0    Sint-Denijslaan
# ...          ...       ...              ...       ...                 ...
# 9868        9868  10308081           Woluwe    1200.0           Rue Voot
# 9869        9869  10588270          Ixelles    1050.0      Avenue Louise
# 9870        9870  10681183             Gent    9000.0    Nieuwewandeling
# 9871        9871  10643994  Braine-le-Comte    7090.0  Rue de la Station
# 9872        9872  10415978        Le Roeulx    7070.0     Rue d' Houdeng
#
#        Number Type of property Subtype of property   Price Type of sale  ...  \
# 0           6            HOUSE               HOUSE  144000     FOR_SALE  ...
# 1           6            HOUSE               HOUSE  199000     FOR_SALE  ...
# 2          20            HOUSE               VILLA  539000     FOR_SALE  ...
# 3     No info            HOUSE               HOUSE  650000     FOR_SALE  ...
# 4           1            HOUSE  MIXED_USE_BUILDING  850000     FOR_SALE  ...
# ...       ...              ...                 ...     ...          ...  ...
# 9868        4        APARTMENT           APARTMENT  395000     FOR_SALE  ...
# 9869      523        APARTMENT           APARTMENT  485000     FOR_SALE  ...
# 9870       62        APARTMENT           APARTMENT  492986     FOR_SALE  ...
# 9871       45        APARTMENT           APARTMENT   85000     FOR_SALE  ...
# 9872      196        APARTMENT             TRIPLEX   89000     FOR_SALE  ...
#
#       Open fire  Terrace TerraceArea Garden Garden area Surface of the land  \
# 0            No      Yes         NaN      1        25.0                 105
# 1            No      Yes       108.0      1        28.0                 229
# 2            No      Yes        60.0      0         0.0                 911
# 3            No      Yes        10.0      1        90.0                 170
# 4            No      Yes         NaN      0         0.0                 430
# ...         ...      ...         ...    ...         ...                 ...
# 9868         No      Yes         6.0      0         0.0                 NaN
# 9869         No      Yes        28.0      0         0.0             No info
# 9870         No      Yes        74.0      0         0.0             No info
# 9871         No       No         0.0      0         0.0             No info
# 9872         No       No         0.0      0         0.0             No info
#
#       Surface area of the plot of land Number of facades   Swimming pool  \
# 0                                    0                 2              No
# 1                                  104                 2              No
# 2                                  541                 4              No
# 3                                  -45                 2              No
# 4                                 -834                 2              No
# ...                                ...               ...             ...
# 9868                           No info                 2              No
# 9869                           No info                 3              No
# 9870                           No info           no info              No
# 9871                           No info                 2              No
# 9872                           No info                 2              No
#
#      State of the building
# 0                     GOOD
# 1                     GOOD
# 2                   AS_NEW
# 3            TO_BE_DONE_UP
# 4              TO_RENOVATE
# ...                    ...
# 9868                  GOOD
# 9869                   NaN
# 9870               No info
# 9871                   NaN
# 9872                   NaN
#
# [19746 rows x 24 columns]

# %%
# df_clean_data=df.dropna()
df_clean_data = df.copy()

# %%
df_clean_data.shape
# Out:
# (19746, 24)

# %%
df_clean_data= df_clean_data.drop_duplicates()

# %%
df_clean_data.shape
# Out:
# (5185, 24)

# %%
df_clean_data.to_csv('df_clean_data.csv', index=False)

# %%
# mapping = {'No': 0, 'Yes': 1}
# df['Garden'] = df['Garden'].map(mapping)

# %%
print(df_clean_data.shape)
df_clean_data.head()
# Out:
# (19746, 24)
#    Unnamed: 0        id Gemeente  Postcode            Street   Number  \
# 0           0  10686031  Seraing    4100.0     Place Merlot         6
# 1           1  10686030  Seraing    4100.0     Place Merlot         6
# 2           2  10686027     Lede    9340.0       Hoogstraat        20
# 3           3  10686410      NaN       NaN           No info  No info
# 4           4  10686063     Gent    9000.0  Sint-Denijslaan         1
#
#   Type of property Subtype of property   Price Type of sale  ...  Open fire  \
# 0            HOUSE               HOUSE  144000     FOR_SALE  ...         No
# 1            HOUSE               HOUSE  199000     FOR_SALE  ...         No
# 2            HOUSE               VILLA  539000     FOR_SALE  ...         No
# 3            HOUSE               HOUSE  650000     FOR_SALE  ...         No
# 4            HOUSE  MIXED_USE_BUILDING  850000     FOR_SALE  ...         No
#
#    Terrace TerraceArea Garden Garden area Surface of the land  \
# 0      Yes         NaN      1        25.0                 105
# 1      Yes       108.0      1        28.0                 229
# 2      Yes        60.0      0         0.0                 911
# 3      Yes        10.0      1        90.0                 170
# 4      Yes         NaN      0         0.0                 430
#
#    Surface area of the plot of land Number of facades   Swimming pool  \
# 0                                 0                 2              No
# 1                               104                 2              No
# 2                               541                 4              No
# 3                               -45                 2              No
# 4                              -834                 2              No
#
#   State of the building
# 0                  GOOD
# 1                  GOOD
# 2                AS_NEW
# 3         TO_BE_DONE_UP
# 4           TO_RENOVATE
#
# [5 rows x 24 columns]

# %% [markdown]
# What are the most expensive municipalities in Belgium? (Average price, median price, price per square meter)

# %%
# df_locality_price = df_clean_data.groupby('Gemeente')['Price'].mean()
# df_locality_price.sort_values(ascending=False).head(10)
df_locality_price = df_clean_data.groupby('Gemeente')['Price'].median()
df_locality_price.sort_values(ascending=False).head(10)
# for col in df_clean_data.columns:
#     print(col)
# df_clean_data["Living Area"]
# filtered_df=df_clean_data[df_clean_data['Gemeente'] == 'Gent']['Price']
# filtered_df
# Out:
# Gemeente
# RHODE-SAINT-GENESE     2950000.0
# Schilde                2124500.0
# Lasne                  1950000.0
# Hoeilaart              1847500.0
# Ruddervoorde           1790000.0
# Gent - Mariakerke      1560000.0
# sint-martens-latem     1545000.0
# Watermael-Boitsfort    1450000.0
# Court-Saint-Etienne    1342500.0
# Knokke - Heist         1295000.0
# Name: Price, dtype: float64

# %%
df_localities = pd.read_excel("Data/Belgiesche_gemeenten_met_postcodes.xlsx")
df_localities = df_localities[['Postcode', 'Provincie']].drop_duplicates().reset_index(drop=True)
print(df_localities.head())
# Out:
#    Postcode                       Provincie
# 0      1000  Brussels Hoofdstedelijk Gewest
# 1      1030  Brussels Hoofdstedelijk Gewest
# 2      1040  Brussels Hoofdstedelijk Gewest
# 3      1050  Brussels Hoofdstedelijk Gewest
# 4      1060  Brussels Hoofdstedelijk Gewest

# %%
df_localities['Gemeenschap'] = np.where(
    df_localities.Provincie.isin(['Vlaams-Brabant', 'Antwerpen', 'Limburg', 'West-Vlaanderen', 'Oost-Vlaanderen']),
    'Flanders',
    np.where(df_localities.Provincie == 'Brussels Hoofdstedelijk Gewest',
             'Brussels',
             'Wallonia'
    )
)

# %%
df_localities
# Out:
#       Postcode                       Provincie Gemeenschap
# 0         1000  Brussels Hoofdstedelijk Gewest    Brussels
# 1         1030  Brussels Hoofdstedelijk Gewest    Brussels
# 2         1040  Brussels Hoofdstedelijk Gewest    Brussels
# 3         1050  Brussels Hoofdstedelijk Gewest    Brussels
# 4         1060  Brussels Hoofdstedelijk Gewest    Brussels
# ...        ...                             ...         ...
# 1138      9981                 Oost-Vlaanderen    Flanders
# 1139      9982                 Oost-Vlaanderen    Flanders
# 1140      9988                 Oost-Vlaanderen    Flanders
# 1141      9991                 Oost-Vlaanderen    Flanders
# 1142      9992                 Oost-Vlaanderen    Flanders
#
# [1143 rows x 3 columns]

# %%
# df_clean_data.drop(columns=['Provincie_x', 'index', 'Provincie_y', 'Gemeenschap'], inplace=True)

# %%
df_clean_data = df_clean_data.merge(df_localities, on=['Postcode'], how='left')
df_clean_data
# Out:
#        Unnamed: 0        id         Gemeente  Postcode              Street  \
# 0               0  10686031          Seraing    4100.0       Place Merlot
# 1               1  10686030          Seraing    4100.0       Place Merlot
# 2               2  10686027             Lede    9340.0         Hoogstraat
# 3               3  10686410              NaN       NaN             No info
# 4               4  10686063             Gent    9000.0    Sint-Denijslaan
# ...           ...       ...              ...       ...                 ...
# 19741        9868  10308081           Woluwe    1200.0           Rue Voot
# 19742        9869  10588270          Ixelles    1050.0      Avenue Louise
# 19743        9870  10681183             Gent    9000.0    Nieuwewandeling
# 19744        9871  10643994  Braine-le-Comte    7090.0  Rue de la Station
# 19745        9872  10415978        Le Roeulx    7070.0     Rue d' Houdeng
#
#         Number Type of property Subtype of property   Price Type of sale  ...  \
# 0            6            HOUSE               HOUSE  144000     FOR_SALE  ...
# 1            6            HOUSE               HOUSE  199000     FOR_SALE  ...
# 2           20            HOUSE               VILLA  539000     FOR_SALE  ...
# 3      No info            HOUSE               HOUSE  650000     FOR_SALE  ...
# 4            1            HOUSE  MIXED_USE_BUILDING  850000     FOR_SALE  ...
# ...        ...              ...                 ...     ...          ...  ...
# 19741        4        APARTMENT           APARTMENT  395000     FOR_SALE  ...
# 19742      523        APARTMENT           APARTMENT  485000     FOR_SALE  ...
# 19743       62        APARTMENT           APARTMENT  492986     FOR_SALE  ...
# 19744       45        APARTMENT           APARTMENT   85000     FOR_SALE  ...
# 19745      196        APARTMENT             TRIPLEX   89000     FOR_SALE  ...
#
#        Garden area  Surface of the land Surface area of the plot of land  \
# 0             25.0                  105                                0
# 1             28.0                  229                              104
# 2              0.0                  911                              541
# 3             90.0                  170                              -45
# 4              0.0                  430                             -834
# ...            ...                  ...                              ...
# 19741          0.0                  NaN                          No info
# 19742          0.0              No info                          No info
# 19743          0.0              No info                          No info
# 19744          0.0              No info                          No info
# 19745          0.0              No info                          No info
#
#       Number of facades  Swimming pool State of the building  \
# 0                     2             No                  GOOD
# 1                     2             No                  GOOD
# 2                     4             No                AS_NEW
# 3                     2             No         TO_BE_DONE_UP
# 4                     2             No           TO_RENOVATE
# ...                 ...            ...                   ...
# 19741                 2             No                  GOOD
# 19742                 3             No                   NaN
# 19743           no info             No               No info
# 19744                 2             No                   NaN
# 19745                 2             No                   NaN
#
#                           Provincie_x Gemeenschap_x  \
# 0                               Liège      Wallonia
# 1                               Liège      Wallonia
# 2                     Oost-Vlaanderen      Flanders
# 3                                 NaN           NaN
# 4                     Oost-Vlaanderen      Flanders
# ...                               ...           ...
# 19741  Brussels Hoofdstedelijk Gewest      Brussels
# 19742  Brussels Hoofdstedelijk Gewest      Brussels
# 19743                 Oost-Vlaanderen      Flanders
# 19744                         Hainaut      Wallonia
# 19745                         Hainaut      Wallonia
#
#                           Provincie_y Gemeenschap_y
# 0                               Liège      Wallonia
# 1                               Liège      Wallonia
# 2                     Oost-Vlaanderen      Flanders
# 3                                 NaN           NaN
# 4                     Oost-Vlaanderen      Flanders
# ...                               ...           ...
# 19741  Brussels Hoofdstedelijk Gewest      Brussels
# 19742  Brussels Hoofdstedelijk Gewest      Brussels
# 19743                 Oost-Vlaanderen      Flanders
# 19744                         Hainaut      Wallonia
# 19745                         Hainaut      Wallonia
#
# [19746 rows x 28 columns]

# %%
import matplotlib.pyplot as plt

# %%
df_price_scatter= df.plot(y="Price", x="Number_ of_rooms", kind="scatter")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File e:\immo_eliza_scrapping_group7\en_immo\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File e:\immo_eliza_scrapping_group7\en_immo\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File e:\immo_eliza_scrapping_group7\en_immo\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Number_ of_rooms'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 df_price_scatter= df.plot(y="Price", x="Number_ of_rooms", kind="scatter")
#
# File e:\immo_eliza_scrapping_group7\en_immo\Lib\site-packages\pandas\plotting\_core.py:920, in PlotAccessor.__call__(self, *args, **kwargs)
#     918 if kind in self._dataframe_kinds:
#     919     if isinstance(data, ABCDataFrame):
# --> 920         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     921     else:
#     922         raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# File e:\immo_eliza_scrapping_group7\en_immo\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File e:\immo_eliza_scrapping_group7\en_immo\Lib\site-packages\pandas\plotting\_matplotlib\core.py:448, in MPLPlot.generate(self)
#     446 self._compute_plot_data()
#     447 self._setup_subplots()
# --> 448 self._make_plot()
#     449 self._add_table()
#     450 self._make_legend()
#
# File e:\immo_eliza_scrapping_group7\en_immo\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1259, in ScatterPlot._make_plot(self)
#    1256 else:
#    1257     label = None
#    1258 scatter = ax.scatter(
# -> 1259     data[x].values,
#    1260     data[y].values,
#    1261     c=c_values,
#    1262     label=label,
#    1263     cmap=cmap,
#    1264     norm=norm,
#    1265     **self.kwds,
#    1266 )
#    1267 if cb:
#    1268     cbar_label = c if c_is_column else ""
#
# File e:\immo_eliza_scrapping_group7\en_immo\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File e:\immo_eliza_scrapping_group7\en_immo\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Number_ of_rooms'

# %%
# Making a plot
x= df_house["Price"]
y= df_apartement["Price"]
data=[x,y]
plt.boxplot(data,patch_artist=True,labels=["House", "Apartment"]) 
plt.title("Price of properties")
# display the plot
plt.show()

# %%
import numpy
import seaborn as sns
# %matplotlib inline

# %%
df_non_string = df.select_dtypes(exclude=['object'])

df_non_string
# Out:
#        Price  Number_ of_rooms  Living_area  Area_Terrace  Area_Garden  \
# 0     749000                 5          NaN            14        152.0
# 1     135000                 5          NaN             0          0.0
# 2     755000                 5          NaN            33        300.0
# 3     295000                 5          NaN             0          0.0
# 4     149000                 2          NaN             0         25.0
# ...      ...               ...          ...           ...          ...
# 5003  275000                 2          NaN            18          NaN
# 5004  275000                 3          NaN             0          NaN
# 5005  275000                 3          NaN             0          NaN
# 5006  279000                 2          NaN             0          NaN
# 5007  279000                 1          NaN             0          NaN
#
#       Land_Surface  Number_of_facades
# 0            220.0                2.0
# 1             60.0                2.0
# 2            500.0                4.0
# 3            160.0                2.0
# 4            105.0                2.0
# ...            ...                ...
# 5003           NaN                4.0
# 5004           NaN                NaN
# 5005           NaN                NaN
# 5006           NaN                2.0
# 5007           NaN                NaN
#
# [10015 rows x 7 columns]

# %%
df_non_string= df_non_string.drop(["Living_area"],axis=1)

corr = df_non_string.select_dtypes('number').corr()

# plot the heatmap
sns.heatmap(corr)
# Out:
# <Axes: >
